# %%
from SSIM_PIL import compare_ssim
from PIL import Image
# Out:
# No module named 'pyopencl'. cl12 version by Christoph Gohlke for windows is recommended: https://www.lfd.uci.edu/~gohlke/pythonlibs/#pyopencl

# %%
path_1 = "E:\\result_von\\augmentedCycleGAN+重构图片对抗\\1130_mu_real"
path_2 = "E:\\result_von\\augmentedCycleGAN+重构图片对抗\\1130_mu_syn"

# %%
import os
ssim_list = []
for i in range(10000):
    img_1 = Image.open(os.path.join(path_1, str(i) + ".jpg"))
    img_2 = Image.open(os.path.join(path_2, str(i) + ".jpg"))
    ssim = compare_ssim(img_1, img_2)
    ssim_list.append(ssim)
    #break

# %%
ssim_list
# Out:
# [0.6369842019394795,
#  0.6512889431898807,
#  0.5934906630765187,
#  0.6251489897689613,
#  0.5916729482598974,
#  0.6316048586998703,
#  0.5587105037305169,
#  0.5799399124939063,
#  0.6013107021751165,
#  0.6249584280980501,
#  0.5915936955877433,
#  0.6397338573376968,
#  0.5716766023480836,
#  0.5676991999952239,
#  0.6038550054589515,
#  0.5769000102120669,
#  0.5651645276757646,
#  0.5908121050891258,
#  0.6286700096231062,
#  0.6175039722196478,
#  0.6587134620454084,
#  0.6852118293895068,
#  0.6642519640872271,
#  0.5891252241177158,
#  0.6726172480926931,
#  0.5544564609677408,
#  0.5848416294264657,
#  0.6129454974976827,
#  0.5928295279540087,
#  0.5960272563381891,
#  0.5707509437849362,
#  0.6455554751847465,
#  0.5696758968526587,
#  0.6217137761205779,
#  0.6622222362773943,
#  0.5904808098509067,
#  0.5556108070968278,
#  0.6258012067033051,
#  0.6125427404619869,
#  0.6415755892666054,
#  0.6104939203352785,
#  0.6598152132509353,
#  0.5771616798711672,
# ...

# %%
import numpy as np

# %%
np.mean(ssim_list)
# Out:
# 0.5784159538020643
